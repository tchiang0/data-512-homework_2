# %%
import os, json, time, urllib.parse
from dotenv import load_dotenv
import requests
import pandas as pd

# %% [markdown]
# ### Step 1: Getting the Article and Population Data
# widipeidia articles of politicians and data for country populations

# %%
politicians_by_country = pd.read_csv("/Users/dianechiang/Desktop/data_512/data-512-homework_2/politicians_by_country_AUG.2024.csv")
politicians_by_country.head()
# Out:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
population_by_country = pd.read_csv("/Users/dianechiang/Desktop/data_512/data-512-homework_2/population_by_country_AUG.2024.csv")
population_by_country.head()
# Out:
#          Geography  Population
# 0            WORLD      8009.0
# 1           AFRICA      1453.0
# 2  NORTHERN AFRICA       256.0
# 3          Algeria        46.8
# 4            Egypt       105.2

# %% [markdown]
# ### Step 2: Getting Article Quality Predictions
# Get the predicted quality scores for each article in Wikipedia dataset

# %%
#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"
API_HEADER_AGENT = 'User-Agent'

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<tchiang0@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2024'
}

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %%
def request_pageinfo_per_article(article_title = None, 
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT, 
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):
    
    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    if API_HEADER_AGENT not in headers:
        raise Exception(f"The header data should include a '{API_HEADER_AGENT}' field that contains your UW email address.")

    if 'uwnetid@uw' in headers[API_HEADER_AGENT]:
        raise Exception(f"Use your UW email address in the '{API_HEADER_AGENT}' field.")

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
# This is just a list of English Wikipedia article titles that we can use for example requests
ARTICLE_TITLES = politicians_by_country['name'].tolist()

# %%
ARTICLE_REVISIONS = [None] * len(ARTICLE_TITLES)

# %%
for idx, article in enumerate(ARTICLE_TITLES):
    info = request_pageinfo_per_article(article)
    lastrevid = None
    for page_id, page_info in info['query']['pages'].items():
        if page_id != "-1":
            print(f"{article} has page id {page_id}")
            lastrevid = page_info['lastrevid']
        ARTICLE_REVISIONS[idx] = lastrevid
    print(f"{article} has lastrevid: {lastrevid}")
# Out:
# Majah Ha Adrif has page id 10483286
# Majah Ha Adrif has lastrevid: 1233202991
# Haroon al-Afghani has page id 11966231
# Haroon al-Afghani has lastrevid: 1230459615
# Tayyab Agha has page id 46841383
# Tayyab Agha has lastrevid: 1225661708
# Khadija Zahra Ahmadi has page id 71600382
# Khadija Zahra Ahmadi has lastrevid: 1234741562
# Aziza Ahmadyar has page id 47805901
# Aziza Ahmadyar has lastrevid: 1195651393
# Muqadasa Ahmadzai has page id 70019038
# Muqadasa Ahmadzai has lastrevid: 1235521766
# Mohammad Sarwar Ahmedzai has page id 27664854
# Mohammad Sarwar Ahmedzai has lastrevid: 1176429234
# Amir Muhammad Akhundzada has page id 12084570
# Amir Muhammad Akhundzada has lastrevid: 1247931713
# Nasrullah Baryalai Arsalai has page id 22588409
# Nasrullah Baryalai Arsalai has lastrevid: 1225385278
# Abdul Rahim Ayoubi has page id 44482763
# Abdul Rahim Ayoubi has lastrevid: 1226326055
# Ismael Balkhi has page id 25153929
# Ismael Balkhi has lastrevid: 1244521219
# Abdul Baqi Turkistani has page id 27428272
# Abdul Baqi Turkistani has lastrevid: 1231655023
# Mohammad Ghous Bashiri has page id 40960242
# Mohammad Ghous Bashiri has lastrevid: 1237694188
# Jan Baz has page id 10305348
# Ibrahim Karbunara has page id 65554476
# Ibrahim Karbunara has lastrevid: 1235824719
# Ali Këlcyra has page id 26297658
# Ali Këlcyra has lastrevid: 1227369252
# Bajram Kelmendi has page id 17273406
# Bajram Kelmendi has lastrevid: 1237006808
# Kristo Kirka has page id 44712134
# Kristo Kirka has lastrevid: 1237950375
# Elez Koçi has page id 18022058
# Elez Koçi has lastrevid: 1174010569
# Xhelal Koprëncka has page id 19887745
# Xhelal Koprëncka has lastrevid: 1209148780
# Kryeziu family has page id 40795168
# Kryeziu family has lastrevid: 1236739222
# Artur Kuko has page id 31509315
# Artur Kuko has lastrevid: 1112281132
# Xhavid Leskoviku has page id 70365511
# Xhavid Leskoviku has lastrevid: 1180950536
# Sabit Lulo has page id 28362818
# Sabit Lulo has lastrevid: 1180950488
# Gjon Markagjoni has page id 10398792
# Gjon Markagjoni has lastrevid: 1227760361
# Tefik Mborja has page id 25589553
# Tefik Mborja has lastrevid: 1234673487
# Hysni Milloshi has page id 22352985
# Hysni Milloshi has lastrevid: 1218412314
# Musa Qazimi has page id 58108950
# Musa Qazimi has lastrevid: 1235824584
# Mustafa Ndroqi has page id 32349706
# Mustafa Ndroqi has lastrevid: 1198219291
# Behxhet Nepravishta has page id 30070258
# Behxhet Nepravishta has lastrevid: 1180949734
# Adrian Neritani has page id 5494953
# Adrian Neritani has lastrevid: 1196135017
# Sali Nivica has page id 33944243
# Sali Nivica has lastrevid: 1240539074
# Thoma Orologa has page id 30250352
# Thoma Orologa has lastrevid: 1180949774
# Bedri Pejani has page id 19888020
# Bedri Pejani has lastrevid: 1220757655
# Kadri Prishtina has page id 41883528
# Kadri Prishtina has lastrevid: 1198167947
# Ymer Prizreni has page id 15757646
# Ymer Prizreni has lastrevid: 1215667416
# Avni Rustemi has page id 14069803
# Avni Rustemi has lastrevid: 1229276965
# Chatin Sarachi has page id 9088115
# Chatin Sarachi has lastrevid: 1141930406
# Nebi Sefa has page id 19887761
# Nebi Sefa has lastrevid: 1244486537
# Eduard Shalsi has page id 31573475
# Eduard Shalsi has lastrevid: 1173107489
# Ylli Vesel Shehu has page id 54102033
# Ylli Vesel Shehu has lastrevid: 1240443327
# Athanas Shundi has page id 68783046
# Athanas Shundi has lastrevid: 1220369492
# Xhelal Sveçla has page id 71208531
# Xhelal Sveçla has lastrevid: 1217259369
# Mehmet Tahsini has page id 28382311
# Mehmet Tahsini has lastrevid: 1239924043
# Ibrahim Temo has page id 27611512
# Ibrahim Temo has lastrevid: 1228151428
# Afrim Tole has page id 63869149
# Afrim Tole has lastrevid: 1241836925
# Syreja Vlora has page id 19887929
# Syreja Vlora has lastrevid: 1186986269
# Visarion Xhuvani has page id 41653012
# Visarion Xhuvani has lastrevid: 1135323365
# Visar Ymeri has page id 31973610
# Visar Ymeri has lastrevid: 1248230838
# Abdyl Ypi has page id 61607609
# Abdyl Ypi has lastrevid: 1220281072
# Xhezair Zaganjori has page id 20381423
# Xhezair Zaganjori has lastrevid: 1143896123
# Menduh Zavalani has page id 55668009
# Israel Ori has page id 5313724
# Israel Ori has lastrevid: 1214986895
# Paul Paul has page id 38740149
# Paul Paul has lastrevid: 1215924661
# Garo Paylan has page id 50404059
# Garo Paylan has lastrevid: 1249622641
# Genrikh Poghosyan has page id 34177704
# Genrikh Poghosyan has lastrevid: 1214662694
# Ishkhan Saghatelyan has page id 67643004
# Ishkhan Saghatelyan has lastrevid: 1243510830
# Karen Sargsyan (sociologist) has page id 74152574
# Karen Sargsyan (sociologist) has lastrevid: 1217803359
# Martiros Sarukhanyan has page id 42075810
# Martiros Sarukhanyan has lastrevid: 1214669503
# Vartkes Serengülian has page id 19929382
# Vartkes Serengülian has lastrevid: 1214669611
# Suren Shadunts has page id 8048537
# Suren Shadunts has lastrevid: 1242146414
# Ohannes Tchekidjian has page id 41520046
# Ohannes Tchekidjian has lastrevid: 1215201883
# Hrayr Tovmasyan has page id 63774722
# Hrayr Tovmasyan has lastrevid: 1243511026
# Usub Bek Temuryan has page id 66901795
# Usub Bek Temuryan has lastrevid: 1243494457
# Kegham Vanigian has page id 40573188
# Kegham Vanigian has lastrevid: 1214670011
# Serop Zakaryan has page id 54156092
# Serop Zakaryan has lastrevid: 1222543352
# Alfons Adam has page id 67603883
# Alfons Adam has lastrevid: 1244617588
# Ingo Appelt has page id 4252669
# Ingo Appelt has lastrevid: 1244447844
# Maximilian Anton Karl, Count Baillet de Latour has page id 26429545
# Maximilian Anton Karl, Count Baillet de Latour has lastrevid: 1226152632
# Heinrich Alfred Barb has page id 48931564
# Heinrich Alfred Barb has lastrevid: 1214670404
# Leopold Berchtold has page id 862679
# Leopold Berchtold has lastrevid: 1228353209
# Joseph Buttinger has page id 4825936
# Joseph Buttinger has lastrevid: 1214670744
# Prince Carl of Solms-Braunfels has page id 3946756
# Prince Carl of Solms-Braunfels has lastrevid: 1237091760
# Count Václav Antonín Chotek of Chotkov and Vojnín has page id 19949832
# Count Václav Antonín Chotek of Chotkov and Vojnín has lastrevid: 1214682376
# Citizens' Ministry has page id 37015016
# Citizens' Ministry has lastrevid: 1200893975
# Richard von Coudenhove-Kalergi has page id 42869603
# Richard von Coudenhove-Kalergi has lastrevid: 1243336388
# Franz Dinghofer has page id 77411982
# Franz Dinghofer has lastrevid: 1244619292
# George Abraham von Dyhrn has page id 31313608
# George Abraham von Dyhrn has lastrevid: 1231555745
# Eduard von Grebmer zu Wolfsthurn has page id 76374912
# Eduard von Grebmer zu Wolfsthurn has lastrevid: 1216075327
# Barbara Eibinger-Miedl has lastrevid: None
# Hans Ferlitsch has page id 4197699
# Hans Ferlitsch has lastrevid: 1240489075
# Friedhelm Frischenschlager has page id 38346616
# Friedhelm Frischenschlager has lastrevid: 1223497595
# Walter Guggenberger has page id 25145889
# Walter Guggenberger has lastrevid: 1154443829
# Ulrich Habsburg-Lothringen has page id 46179557
# Ulrich Habsburg-Lothringen has lastrevid: 1216088776
# Ernst Hampel (politician) has page id 63115789
# Ernst Hampel (politician) has lastrevid: 1232067132
# Hans Peter Haselsteiner has page id 36079970
# Leopold Poetsch has lastrevid: 1248552155
# Thomas Prinzhorn has page id 28636801
# Thomas Prinzhorn has lastrevid: 1215185462
# Gregor Razumovsky (activist) has page id 74627821
# Gregor Razumovsky (activist) has lastrevid: 1236098636
# Horst Rosenkranz has page id 27135394
# Horst Rosenkranz has lastrevid: 1215185628
# Emil Sax has page id 5612787
# Emil Sax has lastrevid: 1215185845
# Peter Schieder has page id 76198558
# Peter Schieder has lastrevid: 1239601735
# Karl Schmitzer has page id 50536736
# Karl Schmitzer has lastrevid: 1215186109
# Sonja Zwazl has page id 77177053
# Sonja Zwazl has lastrevid: 1235856770
# Georg Adam, Prince of Starhemberg has page id 42418604
# Georg Adam, Prince of Starhemberg has lastrevid: 1215186237
# Gundaker Thomas Starhemberg has page id 49426725
# Gundaker Thomas Starhemberg has lastrevid: 1246777408
# Josef Staribacher has page id 41832717
# Josef Staribacher has lastrevid: 1215186443
# Peter Strasser (politician) has page id 76188791
# Peter Strasser (politician) has lastrevid: 1240951343
# Julius Tandler has page id 16195728
# Julius Tandler has lastrevid: 1153989705
# Leopold, Count von Thun und Hohenstein has page id 14600677
# Leopold, Count von Thun und Hohenstein has lastrevid: 1215186791
# Karl Freiherr von Vogelsang has page id 4999454
# Karl Freiherr von Vogelsang has lastrevid: 1231556362
# Anton von Winzor has page id 749702
# Anton von Winzor has lastrevid: 1231556425
# Gisela Wurm has page id 68435651
# Gisela Wurm has lastrevid: 1215187415
# Alexander Zach has page id 7919394
# Alexander Zach has lastrevid: 1215187552
# Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau has page id 19358024
# Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau has lastrevid: 1243965585
# Karl von Zinzendorf has page id 28341664
# Karl von Zinzendorf has lastrevid: 1240906258
# Muzamil Abdullayev has page id 71057696
# Muzamil Abdullayev has lastrevid: 1223484511
# Leyla Abdullayeva has page id 66505277
# Leyla Abdullayeva has lastrevid: 1230366514
# Elchin Afandiyev has page id 29360859
# Elchin Afandiyev has lastrevid: 1243626881
# Fazail Agamali has page id 64212742
# Fazail Agamali has lastrevid: 1240828387
# Aliabbas Salahzade has page id 75545138
# Aliabbas Salahzade has lastrevid: 1211047878
# Enver Alikhanov has page id 52593010
# Enver Alikhanov has lastrevid: 1161577254
# Tarlan Aliyarbayov has page id 66499801
# Tarlan Aliyarbayov has lastrevid: 1240965677
# Dilara Aliyeva has page id 10253465
# Dilara Aliyeva has lastrevid: 1236388140
# Araz Alizadeh has page id 71947937
# Araz Alizadeh has lastrevid: 1246060446
# Ali Asadov has page id 62074177
# Ali Asadov has lastrevid: 1237483914
# Ashraf Bey Taghiyev has page id 76189327
# Ashraf Bey Taghiyev has lastrevid: 1213943020
# Chimnaz Aslanova has page id 75660406
# Chimnaz Aslanova has lastrevid: 1245503366
# Akram Aylisli has page id 38404400
# Akram Aylisli has lastrevid: 1247420701
# Sahil Babayev has page id 63784079
# Sahil Babayev has lastrevid: 1207600921
# Huseyngulu Baghirov has page id 29447701
# Huseyngulu Baghirov has lastrevid: 1199215674
# Bakhish bey Rustambeyov has page id 76441463
# Bakhish bey Rustambeyov has lastrevid: 1246060690
# Alovsat Bakhshiyev has page id 33052057
# Alovsat Bakhshiyev has lastrevid: 1207738330
# Mirgasim Cheshmazer has page id 75670592
# Mirgasim Cheshmazer has lastrevid: 1226415908
# Vilayat Eyvazov has page id 65319366
# Vilayat Eyvazov has lastrevid: 1208072134
# Abdurrahman Fatalibeyli has page id 9465756
# Abdurrahman Fatalibeyli has lastrevid: 1241052691
# Fazail Ibrahimli has page id 71089676
# Fazail Ibrahimli has lastrevid: 1243509483
# Afshan Gadimbeyova has page id 73701173
# Afshan Gadimbeyova has lastrevid: 1243747432
# Garib Karimoğlu has page id 76441761
# Garib Karimoğlu has lastrevid: 1246060699
# Gudrat Gasanguliev has page id 76013404
# Gudrat Gasanguliev has lastrevid: 1234004989
# Mehrali Gasimov has lastrevid: None
# Solomon Grobshtein has page id 13188885
# Solomon Grobshtein has lastrevid: 1067081975
# Teymur Guliyev has page id 52592892
# Teymur Guliyev has lastrevid: 1232296078
# Mammad Gurbanov has page id 66066441
# Mammad Gurbanov has lastrevid: 1237445893
# Musa Hacigasimov has page id 75864792
# Musa Hacigasimov has lastrevid: 1236490449
# Asaf Hajiyev has page id 50559566
# Asaf Hajiyev has lastrevid: 1235219197
# Haji Molla Ahmad Nuruzade has page id 76325547
# Haji Molla Ahmad Nuruzade has lastrevid: 1239189558
# Farhad Hajiyev has page id 66711673
# Farhad Hajiyev has lastrevid: 1246286594
# Hasan Majidov has page id 75801198
# Hasan Majidov has lastrevid: 1236490430
# Hasan Hasanli has page id 72909644
# Hasan Hasanli has lastrevid: 1244589428
# Jamil Hasanli has page id 33064998
# Jamil Hasanli has lastrevid: 1248447237
# Ali M. Hasanov has page id 29805797
# Ali M. Hasanov has lastrevid: 1245282668
# Zakir Hasanov has page id 40963939
# Zakir Hasanov has lastrevid: 1224596001
# Ali Huseynli has page id 63443500
# Ali Huseynli has lastrevid: 1245270394
# Alisahib Huseynov has page id 44931890
# Alisahib Huseynov has lastrevid: 1246588423
# Ali Ibrahimov has page id 52606271
# Ali Ibrahimov has lastrevid: 1244157806
# Irshad Aliyev has page id 76890519
# Irshad Aliyev has lastrevid: 1225308278
# Mamed Iskenderov has page id 52592974
# Mamed Iskenderov has lastrevid: 1244201378
# Vidadi Isgandarov has page id 36758770
# Vidadi Isgandarov has lastrevid: 1249203876
# Ajdar Ismailov has page id 52050192
# Ajdar Ismailov has lastrevid: 1157124148
# Saftar Jafarov has page id 68359822
# Saftar Jafarov has lastrevid: 1222623261
# Jeyhun Jalilov has page id 77024072
# Jeyhun Jalilov has lastrevid: 1228687346
# Arastun Javadov has page id 73414366
# Arastun Javadov has lastrevid: 1147579900
# Rovshan Javadov has page id 3197492
# Rovshan Javadov has lastrevid: 1250266366
# Anar Karimov has page id 64997636
# Anar Karimov has lastrevid: 1245270299
# Boris Kevorkov has page id 20488566
# Boris Kevorkov has lastrevid: 1217681945
# Gurban Khalilov has page id 65640632
# Gurban Khalilov has lastrevid: 1243520102
# Ahmad Kordary has page id 57656422
# Ahmad Kordary has lastrevid: 1187254621
# Lutfali bey Behbudov has page id 75784519
# Lutfali bey Behbudov has lastrevid: 1226230854
# Ilham Madatov has page id 45628825
# Ilham Madatov has lastrevid: 1011331249
# Makhmud Mamed-Guliev has page id 76496477
# Makhmud Mamed-Guliev has lastrevid: 1243510539
# Majnun Mammadov has page id 73560444
# Majnun Mammadov has lastrevid: 1248225337
# Musa Mammadov has page id 70572331
# Musa Mammadov has lastrevid: 1243510550
# Ramin Mammadov has page id 66923230
# Ramin Mammadov has lastrevid: 1248662299
# Elshad Mirbashir oghlu has page id 63969137
# Elshad Mirbashir oghlu has lastrevid: 1194162044
# Tahir Mirkishili has page id 75539115
# Tahir Mirkishili has lastrevid: 1210593900
# Movsum Samadov has page id 75252047
# Movsum Samadov has lastrevid: 1241255046
# Fuad Naghiyev has page id 66166950
# Fuad Naghiyev has lastrevid: 1248662296
# Eldar Namazov has page id 30612315
# Eldar Namazov has lastrevid: 1206211739
# Namig Nasrullayev has page id 72787223
# Namig Nasrullayev has lastrevid: 1158375491
# Siyavush Novruzov has page id 59571031
# Siyavush Novruzov has lastrevid: 1243520070
# Zahid Oruj has page id 73057190
# Zahid Oruj has lastrevid: 1213965350
# Sadig Rahimov has page id 52592948
# Sadig Rahimov has lastrevid: 1245157534
# Suleyman Rahimov has page id 59439237
# Suleyman Rahimov has lastrevid: 1193027962
# Huseyn Rahmanov has page id 52592854
# Huseyn Rahmanov has lastrevid: 1106104383
# Rovshen Rzayev has page id 75573577
# Rovshen Rzayev has lastrevid: 1208078338
# Hasan Seyidov has page id 52606355
# Hasan Seyidov has lastrevid: 1148385245
# Hasan Seyidov (scientist) has page id 73749273
# Hasan Seyidov (scientist) has lastrevid: 1198202282
# Parviz Shahbazov has page id 61498150
# Parviz Shahbazov has lastrevid: 1213858589
# Mammad agha Shahtakhtinski has page id 19551770
# Mammad agha Shahtakhtinski has lastrevid: 1185599926
# Abid Sharifov has page id 29387873
# Abid Sharifov has lastrevid: 1243510547
# Shirali Akhundov has page id 72968230
# Shirali Akhundov has lastrevid: 1213002608
# Ikhtiyar Shirinov has page id 72266644
# Ikhtiyar Shirinov has lastrevid: 1243510572
# Bakhtiyar Vahabzadeh has page id 4750890
# Bakhtiyar Vahabzadeh has lastrevid: 1249675761
# Vugar Mustafayev (minister) has page id 75356945
# Vugar Mustafayev (minister) has lastrevid: 1208077047
# Yusif Ziya Talibzadeh has page id 73087745
# Yusif Ziya Talibzadeh has lastrevid: 1243510546
# Nurali Yusifbayli has page id 50497831
# Nurali Yusifbayli has lastrevid: 1243510541
# Keith Bell (Bahamian politician) has page id 77294368
# Keith Bell (Bahamian politician) has lastrevid: 1243023554
# Charles Carter (Bahamian journalist) has page id 74118304
# Charles Carter (Bahamian journalist) has lastrevid: 1162793449
# Harold Christie has page id 64192552
# Harold Christie has lastrevid: 1142294843
# Timothy Donaldson has page id 38803441
# ...
# Fidel Barbarito has lastrevid: 1246246398
# Pedro Bastidas has page id 67472967
# Pedro Bastidas has lastrevid: 1232135029
# Nguyễn Dương Đôn has lastrevid: 1177240282
# Nguyễn Duy Quý has page id 70737547
# Nguyễn Duy Quý has lastrevid: 1245479331
# Nguyễn Hợp Đoàn has page id 2868214
# Nguyễn Hợp Đoàn has lastrevid: 1232872822
# Nguyễn Phan Long has page id 5112809
# Nguyễn Phan Long has lastrevid: 1221992596
# Nguyễn Quốc Cường has page id 6503846
# Nguyễn Quốc Cường has lastrevid: 1130925190
# Nguyễn Thị Hồng (economist) has page id 65825771
# Nguyễn Thị Hồng (economist) has lastrevid: 1214023850
# Nguyễn Thị Thập has page id 38592621
# Nguyễn Thị Thập has lastrevid: 1145703738
# Nguyễn Văn Huyền has page id 56460119
# Nguyễn Văn Huyền has lastrevid: 1241609893
# Nguyễn Văn Lực has page id 28646034
# Nguyễn Văn Lực has lastrevid: 1106652276
# Nguyễn Văn Trân has page id 59398978
# Nguyễn Văn Trân has lastrevid: 1245671291
# Nguyễn Văn Xuân has page id 5112934
# Nguyễn Văn Xuân has lastrevid: 1231154121
# Phan Anh has page id 76610838
# Phan Anh has lastrevid: 1224595790
# Tạ Quang Bửu has page id 76618321
# Tạ Quang Bửu has lastrevid: 1224595798
# Tran Minh Tiet has page id 46532179
# Tran Minh Tiet has lastrevid: 1225066058
# Trần Quốc Vượng (politician) has page id 68474844
# Trần Quốc Vượng (politician) has lastrevid: 1237490552
# Trần Văn Hữu has page id 5112795
# Trần Văn Hữu has lastrevid: 1244544286
# Trương Đình Dzu has page id 18577286
# Trương Đình Dzu has lastrevid: 1220804010
# Võ Văn Thưởng has page id 68059621
# Võ Văn Thưởng has lastrevid: 1241845313
# Abdullah Noman has page id 74184047
# Abdullah Noman has lastrevid: 1248329006
# Hashid Abdullah al-Ahmar has page id 32102626
# Hashid Abdullah al-Ahmar has lastrevid: 1247681421
# Himyar Abdullah al-Ahmar has page id 72698869
# Himyar Abdullah al-Ahmar has lastrevid: 1247681426
# Sam Yahya Al-Ahmar has page id 32102621
# Sam Yahya Al-Ahmar has lastrevid: 1247681434
# Ameen Ali al-Akimi has page id 71734050
# Ameen Ali al-Akimi has lastrevid: 1139612517
# Talal Aklan has page id 51352550
# Talal Aklan has lastrevid: 1242218278
# Abdullatif Al-Sayed has page id 57088432
# Abdullatif Al-Sayed has lastrevid: 1231304528
# Muhammad Musa al-Amri has page id 47319379
# Muhammad Musa al-Amri has lastrevid: 1144463258
# Mohamed al-Atifi has page id 52703239
# Mohamed al-Atifi has lastrevid: 1243159603
# Yasser Al-Awadi has page id 69290070
# Yasser Al-Awadi has lastrevid: 1129096674
# Sagheer Hamoud Aziz has page id 71422532
# Sagheer Hamoud Aziz has lastrevid: 1247681445
# Sultan al-Barakani has page id 71726180
# Sultan al-Barakani has lastrevid: 1246507826
# Faraj Salmin Al-Bahsani has page id 71436343
# Faraj Salmin Al-Bahsani has lastrevid: 1216872257
# Ali Al Bukhaiti has page id 66837148
# Ali Al Bukhaiti has lastrevid: 1249864801
# Bruce Conde has page id 24619602
# Bruce Conde has lastrevid: 1243942923
# Khayisa Ndiweni has lastrevid: 1226322430
# Jane Ngwenya has page id 68455814
# Jane Ngwenya has lastrevid: 1199625809
# Maurice Nyagumbo has page id 14158119
# Maurice Nyagumbo has lastrevid: 1225102400
# George Nyandoro has page id 8958861
# George Nyandoro has lastrevid: 1143871016
# Sekai Nzenza has page id 30863116
# Sekai Nzenza has lastrevid: 1241843269
# Engelbert Rugeje has page id 11706047
# Engelbert Rugeje has lastrevid: 1221940918
# Tinos Rusere has page id 9832348
# Tinos Rusere has lastrevid: 1236282175
# Scot Sakupwanya has page id 75594876
# Scot Sakupwanya has lastrevid: 1242611251
# Daniel Shumba has page id 16773271
# Daniel Shumba has lastrevid: 1154573139
# Maxwell Zeb Shumba has page id 49467980
# Maxwell Zeb Shumba has lastrevid: 1246242430
# Nkululeko Mkastos Sibanda has page id 16773427
# Nkululeko Mkastos Sibanda has lastrevid: 1243016866
# Leopold Takawira has page id 8659677
# Leopold Takawira has lastrevid: 1236900271
# Gift Tandare has page id 10031005
# Gift Tandare has lastrevid: 1235705451
# Rekayi Tangwena has page id 23231242
# Rekayi Tangwena has lastrevid: 1236117496
# Temba Mliswa has page id 72159007
# Temba Mliswa has lastrevid: 1246241769
# Josiah Tongogara has page id 633594
# Josiah Tongogara has lastrevid: 1203429435
# Langton Towungana has page id 16375315
# Langton Towungana has lastrevid: 1246280093
# Sengezo Tshabangu has page id 75270547
# Sengezo Tshabangu has lastrevid: 1228478288
# Herbert Ushewokunze has page id 11742819
# Herbert Ushewokunze has lastrevid: 959111842
# Denis Walker has page id 3255571
# Denis Walker has lastrevid: 1247902630

# %% [markdown]
# Make ORES request using the patge title and current revision id

# %%
#########
#
#    CONSTANTS
#

#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = ((60.0*60.0)/5000.0)-API_LATENCY_ASSUMED  # The key authorizes 5000 requests per hour

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#    
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
#
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "<{email_address}>, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}
#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "",         # your email address should go here
    'access_token'  : ""          # the access token you create will need to go here
}
#
#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

load_dotenv()
# wikimedia API access token
ACCESS_TOKEN = os.getenv("ACCESS_TOKEN")

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT, 
                                   model_name = API_ORES_EN_QUALITY_MODEL, 
                                   request_data = ORES_REQUEST_DATA_TEMPLATE, 
                                   header_format = REQUEST_HEADER_TEMPLATE, 
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):
    
    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token
    
    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")
    
    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)
    
    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
ARTICLE_SCORES = [None] * len(ARTICLE_TITLES)
RATINGS = ["B", "C", "FA", "GA", "Start", "Stub"]

# %%
for idx, article_title in enumerate(ARTICLE_TITLES):
    if not ARTICLE_REVISIONS[idx]:
        print(f"{article_title} is not found in wiki")
        continue
    # print(f"Getting LiftWing ORES scores for '{article_title}' with revid: {ARTICLE_REVISIONS[idx]:d}")
    score = request_ores_score_per_article(article_revid=int(ARTICLE_REVISIONS[idx]),
                                           email_address="tchiang0@uw.edu",
                                           access_token=ACCESS_TOKEN)
    if score and 'enwiki' in score:
        rating = score['enwiki']['scores'][str(ARTICLE_REVISIONS[idx])]['articlequality']['score']['prediction']
        if rating in RATINGS:
            ARTICLE_SCORES[idx] = rating
        # print(f"The predicted rating of {article_title} is {ARTICLE_SCORES[idx]}")
    # else:
    #     print(f"ERROR: {score}")
    #     print(f"The predicted rating of {article_title} is {ARTICLE_SCORES[idx]}")
# Out:
# Barbara Eibinger-Miedl is not found in wiki
# Mehrali Gasimov is not found in wiki
# Kyaw Myint is not found in wiki
# André Ngongang Ouandji is not found in wiki
# Tomás Pimentel is not found in wiki
# Richard Sumah is not found in wiki
# Segun ''Aeroland'' Adewale is not found in wiki
# Bashir Bililiqo is not found in wiki

# %%
data = {
    "article_title": ARTICLE_TITLES, 
    "article_rev": ARTICLE_REVISIONS,
    "article_score": ARTICLE_SCORES
}

with open('lists.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
# score error rate: ratio of the number of articles for which you were not able to get a score divided by the total number of articles
print(len(ARTICLE_SCORES))
print(len(ARTICLE_TITLES))
print(len(ARTICLE_REVISIONS))

count_no_score = 0
for article_score in ARTICLE_SCORES:
    if not article_score:
        count_no_score += 1

score_err_rate = count_no_score / len(ARTICLE_TITLES)
print(score_err_rate)
# Out:
# 7155
# 7155
# 7155
# 0.0025157232704402514

# %% [markdown]
# ### Step 3: Combining the Datasets

# %%
# Merge wikipedia data and populution data together
# Merge on country name
# Identify all countries for which there are no matches and output a list of those countries: wp_countries-no_match.txt
# Remaining data into: wp_politicians_by_country.csv
# country/region/population/article_title/revision_id/article_quality
# Out:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#        country    Geography  Population
# 0  Afghanistan  Afghanistan        42.4
# 1  Afghanistan  Afghanistan        42.4
# 2  Afghanistan  Afghanistan        42.4
# 3  Afghanistan  Afghanistan        42.4
# 4  Afghanistan  Afghanistan        42.4

# %%
population_by_country['region'] = None
cur_region = None

meta_regions = ['AFRICA', 'LATIN AMERICA AND THE CARIBBEAN', 'ASIA']
regions = population_by_country[population_by_country['Geography'].str.isupper()]['Geography'].tolist()

for idx, row in population_by_country.iterrows():
    if row['Geography'] in regions and row['Geography'] not in meta_regions:
        cur_region = row['Geography']
        # print(f"cur_region is {cur_region}")

    population_by_country.at[idx, 'region'] = cur_region

# %%
population_by_country
# Out:
#            Geography  Population           region
# 0              WORLD        8009            WORLD
# 1             AFRICA        1453            WORLD
# 2    NORTHERN AFRICA         256  NORTHERN AFRICA
# 3            Algeria          47  NORTHERN AFRICA
# 4              Egypt         105  NORTHERN AFRICA
# ..               ...         ...              ...
# 228            Samoa           0          OCEANIA
# 229  Solomon Islands           1          OCEANIA
# 230            Tonga           0          OCEANIA
# 231           Tuvalu           0          OCEANIA
# 232          Vanuatu           0          OCEANIA
#
# [233 rows x 3 columns]

# %%
print(len(ARTICLE_SCORES))
print(len(ARTICLE_TITLES))
print(len(ARTICLE_REVISIONS))
# Out:
# 7155
# 7155
# 7155

# %%
ARTICLE_SCORES[:10]
# Out:
# ['Start',
#  'B',
#  'Start',
#  'Stub',
#  'Start',
#  'Start',
#  'Start',
#  'Start',
#  'Start',
#  'Start']

# %%
pd.set_option('display.float_format', '{:.0f}'.format)
politicians_by_country['revision_id'] = ARTICLE_REVISIONS
politicians_by_country['article_quality'] = ARTICLE_SCORES
politicians_by_country.head(10)
# Out:
#                          name  \
# 0              Majah Ha Adrif
# 1           Haroon al-Afghani
# 2                 Tayyab Agha
# 3        Khadija Zahra Ahmadi
# 4              Aziza Ahmadyar
# 5           Muqadasa Ahmadzai
# 6    Mohammad Sarwar Ahmedzai
# 7    Amir Muhammad Akhundzada
# 8  Nasrullah Baryalai Arsalai
# 9          Abdul Rahim Ayoubi
#
#                                                  url      country  \
# 0       https://en.wikipedia.org/wiki/Majah_Ha_Adrif  Afghanistan
# 1    https://en.wikipedia.org/wiki/Haroon_al-Afghani  Afghanistan
# 2          https://en.wikipedia.org/wiki/Tayyab_Agha  Afghanistan
# 3  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...  Afghanistan
# 4       https://en.wikipedia.org/wiki/Aziza_Ahmadyar  Afghanistan
# 5    https://en.wikipedia.org/wiki/Muqadasa_Ahmadzai  Afghanistan
# 6  https://en.wikipedia.org/wiki/Mohammad_Sarwar_...  Afghanistan
# 7  https://en.wikipedia.org/wiki/Amir_Muhammad_Ak...  Afghanistan
# 8  https://en.wikipedia.org/wiki/Nasrullah_Baryal...  Afghanistan
# 9   https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi  Afghanistan
#
#    revision_id article_quality
# 0   1233202991           Start
# 1   1230459615               B
# 2   1225661708           Start
# 3   1234741562            Stub
# 4   1195651393           Start
# 5   1235521766           Start
# 6   1176429234           Start
# 7   1247931713           Start
# 8   1225385278           Start
# 9   1226326055           Start

# %%
# some countries are labeled differently (ex. Korea, South vs. Korea (South)) or are not present in the population_by_country.AUG.2024.csv file
merged_df = pd.merge(politicians_by_country, population_by_country, left_on='country', right_on='Geography', how='left').drop(columns=['Geography', 'url'])
merged_df = merged_df.rename(columns={
    'name': 'article_title',
    'Population': 'population'
})

merged_df = merged_df[['country', 'region', 'population', 'article_title', 'revision_id', 'article_quality']]
merged_df
# Out:
#           country          region  population         article_title  \
# 0     Afghanistan      SOUTH ASIA          42        Majah Ha Adrif
# 1     Afghanistan      SOUTH ASIA          42     Haroon al-Afghani
# 2     Afghanistan      SOUTH ASIA          42           Tayyab Agha
# 3     Afghanistan      SOUTH ASIA          42  Khadija Zahra Ahmadi
# 4     Afghanistan      SOUTH ASIA          42        Aziza Ahmadyar
# ...           ...             ...         ...                   ...
# 7150     Zimbabwe  EASTERN AFRICA          17      Josiah Tongogara
# 7151     Zimbabwe  EASTERN AFRICA          17     Langton Towungana
# 7152     Zimbabwe  EASTERN AFRICA          17     Sengezo Tshabangu
# 7153     Zimbabwe  EASTERN AFRICA          17   Herbert Ushewokunze
# 7154     Zimbabwe  EASTERN AFRICA          17          Denis Walker
#
#       revision_id article_quality
# 0      1233202991           Start
# 1      1230459615               B
# 2      1225661708           Start
# 3      1234741562            Stub
# 4      1195651393           Start
# ...           ...             ...
# 7150   1203429435               C
# 7151   1246280093            Stub
# 7152   1228478288           Start
# 7153    959111842            Stub
# 7154   1247902630               C
#
# [7155 rows x 6 columns]

# %%
right_merged_df = pd.merge(politicians_by_country, population_by_country, left_on='country', right_on='Geography', how='right')
right_merged_df
# Out:
#                             name  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3               Abdelkader Zoukh
# 4        Chaâbane Aït Abderrahim
# ...                          ...
# 7075                 Solofa Uota
# 7076             Vincent Lunabek
# 7077        President of Vanuatu
# 7078  Jimmy Stevens (politician)
# 7079               Dinh Van Than
#
#                                                     url  country  revision_id  \
# 0                                                   NaN      NaN          NaN
# 1                                                   NaN      NaN          NaN
# 2                                                   NaN      NaN          NaN
# 3        https://en.wikipedia.org/wiki/Abdelkader_Zoukh  Algeria   1250270534
# 4     https://en.wikipedia.org/wiki/Chaâbane_Aït_Abd...  Algeria   1234096174
# ...                                                 ...      ...          ...
# 7075          https://en.wikipedia.org/wiki/Solofa_Uota   Tuvalu   1242819518
# 7076      https://en.wikipedia.org/wiki/Vincent_Lunabek  Vanuatu   1132674478
# 7077  https://en.wikipedia.org/wiki/President_of_Van...  Vanuatu   1211211712
# 7078  https://en.wikipedia.org/wiki/Jimmy_Stevens_(p...  Vanuatu   1169502061
# 7079        https://en.wikipedia.org/wiki/Dinh_Van_Than  Vanuatu   1244170639
#
#      article_quality        Geography  Population           region
# 0                NaN            WORLD        8009            WORLD
# 1                NaN           AFRICA        1453            WORLD
# 2                NaN  NORTHERN AFRICA         256  NORTHERN AFRICA
# 3              Start          Algeria          47  NORTHERN AFRICA
# 4              Start          Algeria          47  NORTHERN AFRICA
# ...              ...              ...         ...              ...
# 7075            Stub           Tuvalu           0          OCEANIA
# 7076            Stub          Vanuatu           0          OCEANIA
# 7077           Start          Vanuatu           0          OCEANIA
# 7078           Start          Vanuatu           0          OCEANIA
# 7079               C          Vanuatu           0          OCEANIA
#
# [7080 rows x 8 columns]

# %%
regions_not_in_politician = right_merged_df[right_merged_df['name'].isna()]['Geography'].drop_duplicates().values.tolist()
regions_not_in_politician[:5]
# Out:
# ['WORLD', 'AFRICA', 'NORTHERN AFRICA', 'Western Sahara', 'WESTERN AFRICA']

# %%
countries_not_in_population_df = merged_df[merged_df['region'].isna() | (merged_df['article_title'].isna() & ~merged_df['country'].isna())]['country'].drop_duplicates().values.tolist()
countries_not_in_population_df
# Out:
# ['Guinea-Bissau', 'Korean', 'Korea, South']

# %%
with open('wp_countries-no_match.txt', 'w') as outfile:
    for region in regions_not_in_politician:
        outfile.write(region + '\n')
    
    for region in countries_not_in_population_df:
        outfile.write(region + '\n')

# %%
politicians_by_country_df = merged_df[~merged_df['region'].isna()]
politicians_by_country_df.to_csv('wp_politicians_by_country.csv')

# %% [markdown]
# ### Step 4: Analysis

# %%
# Country-by-country and regional basis
# Calculate total-articles-per-capita (a ratio representing the number of articles per person)
# high-quality-per-capita (a ratio representing the number of high quality articles per person) => FA or GA
# A country can only exist in one region
# population_by_country_AUG.2024.csv provides population in millions
pd.options.display.float_format = '{:12.5e}'.format
article_count_per_country = merged_df.groupby(['country'])['article_title'].count()
article_count_per_country_population = pd.merge(article_count_per_country, population_by_country, left_on='country', right_on='Geography').drop(columns=['region'])
article_count_per_country_population = article_count_per_country_population.rename(
    columns={
        'article_title': 'total_article_count',
        'Geography': 'country',
        'Population': 'population'
    }
)
article_count_per_country_population['population'] = article_count_per_country_population['population'] * 10**6
article_count_per_country_population['total_articles_per_capita'] = article_count_per_country_population['total_article_count'] / article_count_per_country_population['population']
article_count_per_country_population = article_count_per_country_population[['country', 'population', 'total_article_count', 'total_articles_per_capita']]
article_count_per_country_population
# Out:
#                  country   population  total_article_count  \
# 0            Afghanistan  4.24000e+07                   85
# 1                Albania  2.70000e+06                   70
# 2                Algeria  4.68000e+07                   71
# 3                 Angola  3.67000e+07                   58
# 4    Antigua and Barbuda  1.00000e+05                   33
# ..                   ...          ...                  ...
# 161            Venezuela  2.88000e+07                   56
# 162              Vietnam  9.89000e+07                   36
# 163                Yemen  3.44000e+07                   32
# 164               Zambia  2.02000e+07                    3
# 165             Zimbabwe  1.67000e+07                   69
#
#      total_articles_per_capita
# 0                  2.00472e-06
# 1                  2.59259e-05
# 2                  1.51709e-06
# 3                  1.58038e-06
# 4                  3.30000e-04
# ..                         ...
# 161                1.94444e-06
# 162                3.64004e-07
# 163                9.30233e-07
# 164                1.48515e-07
# 165                4.13174e-06
#
# [166 rows x 4 columns]

# %%
good_quality_article_score = ['FA', 'GA']

# %%
high_quality_article_count_by_country_df = merged_df.groupby('country')['article_quality'].apply(lambda x: x.isin(good_quality_article_score).sum())
high_quality_article_count_by_country_population_df = pd.merge(high_quality_article_count_by_country_df, population_by_country, left_on='country', right_on='Geography').drop(columns={'region'})
high_quality_article_count_by_country_population_df = high_quality_article_count_by_country_population_df.rename(
    columns={
        'article_quality': 'total_high_quality_article_count',
        'Geography': 'country',
        'Population': 'population'
    }
)
high_quality_article_count_by_country_population_df['high_quality_articles_per_capita'] = high_quality_article_count_by_country_population_df['total_high_quality_article_count'] / high_quality_article_count_by_country_population_df['population']
high_quality_article_count_by_country_population_df = high_quality_article_count_by_country_population_df[['country', 'population', 'total_high_quality_article_count', 'high_quality_articles_per_capita']]
high_quality_article_count_by_country_population_df
# Out:
#                  country   population  total_high_quality_article_count  \
# 0            Afghanistan  4.24000e+01                                 3
# 1                Albania  2.70000e+00                                 7
# 2                Algeria  4.68000e+01                                 1
# 3                 Angola  3.67000e+01                                 2
# 4    Antigua and Barbuda  1.00000e-01                                 0
# ..                   ...          ...                               ...
# 161            Venezuela  2.88000e+01                                 1
# 162              Vietnam  9.89000e+01                                 2
# 163                Yemen  3.44000e+01                                 0
# 164               Zambia  2.02000e+01                                 0
# 165             Zimbabwe  1.67000e+01                                 0
#
#      high_quality_articles_per_capita
# 0                         7.07547e-02
# 1                         2.59259e+00
# 2                         2.13675e-02
# 3                         5.44959e-02
# 4                         0.00000e+00
# ..                                ...
# 161                       3.47222e-02
# 162                       2.02224e-02
# 163                       0.00000e+00
# 164                       0.00000e+00
# 165                       0.00000e+00
#
# [166 rows x 4 columns]

# %%
high_quality_article_count_by_country_population_df.sort_values('total_high_quality_article_count', ascending=False)
# Out:
#           country   population  total_high_quality_article_count  \
# 134         Spain  4.83000e+01                                18
# 67      Indonesia  2.78700e+02                                15
# 119        Russia  1.46900e+02                                 9
# 156       Ukraine  3.67000e+01                                 8
# 132  South Africa  6.07000e+01                                 8
# ..            ...          ...                               ...
# 77         Kuwait  4.40000e+00                                 0
# 70         Israel  9.80000e+00                                 0
# 66          India  1.42860e+03                                 0
# 64       Honduras  9.70000e+00                                 0
# 165      Zimbabwe  1.67000e+01                                 0
#
#      high_quality_articles_per_capita
# 134                       3.72671e-01
# 67                        5.38213e-02
# 119                       6.12662e-02
# 156                       2.17984e-01
# 132                       1.31796e-01
# ..                                ...
# 77                        0.00000e+00
# 70                        0.00000e+00
# 66                        0.00000e+00
# 64                        0.00000e+00
# 165                       0.00000e+00
#
# [166 rows x 4 columns]

# %%
article_count_per_region = merged_df.groupby(['region'])['article_title'].count()
article_count_per_region_population = pd.merge(article_count_per_region, population_by_country, left_on='region', right_on='Geography').drop(columns=['region'])
article_count_per_region_population = article_count_per_region_population.rename(
    columns={
        'article_title': 'total_article_count',
        'Geography': 'region',
        'Population': 'population'
    }
)
article_count_per_region_population['population'] = article_count_per_region_population['population'] * 10**6
article_count_per_region_population['total_articles_per_capita'] = article_count_per_region_population['total_article_count'] / article_count_per_region_population['population']
article_count_per_region_population = article_count_per_region_population[['region', 'population', 'total_article_count', 'total_articles_per_capita']]
article_count_per_region_population
# Out:
#              region   population  total_article_count  \
# 0         CARIBBEAN  4.40000e+07                  219
# 1   CENTRAL AMERICA  1.82000e+08                  188
# 2      CENTRAL ASIA  8.00000e+07                  106
# 3         EAST ASIA  1.64800e+09                  152
# 4    EASTERN AFRICA  4.83000e+08                  665
# 5    EASTERN EUROPE  2.85000e+08                  709
# 6     MIDDLE AFRICA  2.02000e+08                  231
# 7   NORTHERN AFRICA  2.56000e+08                  302
# 8   NORTHERN EUROPE  1.08000e+08                  191
# 9           OCEANIA  4.50000e+07                   72
# 10    SOUTH AMERICA  4.26000e+08                  569
# 11       SOUTH ASIA  2.02900e+09                  670
# 12   SOUTHEAST ASIA  6.82000e+08                  396
# 13  SOUTHERN AFRICA  7.00000e+07                  123
# 14  SOUTHERN EUROPE  1.52000e+08                  797
# 15   WESTERN AFRICA  4.42000e+08                  515
# 16     WESTERN ASIA  2.99000e+08                  610
# 17   WESTERN EUROPE  1.99000e+08                  498
#
#     total_articles_per_capita
# 0                 4.97727e-06
# 1                 1.03297e-06
# 2                 1.32500e-06
# 3                 9.22330e-08
# 4                 1.37681e-06
# 5                 2.48772e-06
# 6                 1.14356e-06
# 7                 1.17969e-06
# 8                 1.76852e-06
# 9                 1.60000e-06
# 10                1.33568e-06
# 11                3.30212e-07
# 12                5.80645e-07
# 13                1.75714e-06
# 14                5.24342e-06
# 15                1.16516e-06
# 16                2.04013e-06
# 17                2.50251e-06

# %%
high_quality_article_count_by_region_df = merged_df.groupby('region')['article_quality'].apply(lambda x: x.isin(good_quality_article_score).sum())
high_quality_article_count_by_region_population_df = pd.merge(high_quality_article_count_by_region_df, population_by_country, left_on='region', right_on='Geography').drop(columns={'Geography'})
high_quality_article_count_by_region_population_df = high_quality_article_count_by_region_population_df.rename(
    columns={
        'article_quality': 'total_high_quality_article_count',
        'Population': 'population'
    }
)

high_quality_article_count_by_region_population_df['high_quality_articles_per_capita'] = high_quality_article_count_by_region_population_df['total_high_quality_article_count'] / high_quality_article_count_by_region_population_df['population']
high_quality_article_count_by_region_population_df = high_quality_article_count_by_region_population_df[['region', 'population', 'total_high_quality_article_count', 'high_quality_articles_per_capita']]
high_quality_article_count_by_region_population_df
# Out:
#              region   population  total_high_quality_article_count  \
# 0         CARIBBEAN  4.40000e+01                                 9
# 1   CENTRAL AMERICA  1.82000e+02                                10
# 2      CENTRAL ASIA  8.00000e+01                                 5
# 3         EAST ASIA  1.64800e+03                                 3
# 4    EASTERN AFRICA  4.83000e+02                                17
# 5    EASTERN EUROPE  2.85000e+02                                38
# 6     MIDDLE AFRICA  2.02000e+02                                 8
# 7   NORTHERN AFRICA  2.56000e+02                                17
# 8   NORTHERN EUROPE  1.08000e+02                                 9
# 9           OCEANIA  4.50000e+01                                 1
# 10    SOUTH AMERICA  4.26000e+02                                19
# 11       SOUTH ASIA  2.02900e+03                                21
# 12   SOUTHEAST ASIA  6.82000e+02                                25
# 13  SOUTHERN AFRICA  7.00000e+01                                 8
# 14  SOUTHERN EUROPE  1.52000e+02                                52
# 15   WESTERN AFRICA  4.42000e+02                                13
# 16     WESTERN ASIA  2.99000e+02                                27
# 17   WESTERN EUROPE  1.99000e+02                                21
#
#     high_quality_articles_per_capita
# 0                        2.04545e-01
# 1                        5.49451e-02
# 2                        6.25000e-02
# 3                        1.82039e-03
# 4                        3.51967e-02
# 5                        1.33333e-01
# 6                        3.96040e-02
# 7                        6.64062e-02
# 8                        8.33333e-02
# 9                        2.22222e-02
# 10                       4.46009e-02
# 11                       1.03499e-02
# 12                       3.66569e-02
# 13                       1.14286e-01
# 14                       3.42105e-01
# 15                       2.94118e-02
# 16                       9.03010e-02
# 17                       1.05528e-01

# %%
high_quality_article_count_by_region_population_df['total_high_quality_article_count'].sum()
# Out:
# np.int64(303)

# %% [markdown]
# ### Step 5: Results

# %%
# Table 1
# Top 10 countries by coverage: The 10 countries with the highest total articles per capita (desc)
article_count_per_country_population.sort_values('total_articles_per_capita', ascending=False).head(12)
# Out:
#                             country   population  total_article_count  \
# 96                           Monaco  0.00000e+00                   10
# 154                          Tuvalu  0.00000e+00                    1
# 4               Antigua and Barbuda  1.00000e+05                   33
# 51   Federated States of Micronesia  1.00000e+05                   14
# 93                 Marshall Islands  1.00000e+05                   13
# 149                           Tonga  1.00000e+05                   10
# 12                         Barbados  3.00000e+05                   25
# 98                       Montenegro  6.00000e+05                   36
# 125                      Seychelles  1.00000e+05                    6
# 90                         Maldives  6.00000e+05                   33
# 17                           Bhutan  8.00000e+05                   44
# 121                           Samoa  2.00000e+05                    8
#
#      total_articles_per_capita
# 96                         inf
# 154                        inf
# 4                  3.30000e-04
# 51                 1.40000e-04
# 93                 1.30000e-04
# 149                1.00000e-04
# 12                 8.33333e-05
# 98                 6.00000e-05
# 125                6.00000e-05
# 90                 5.50000e-05
# 17                 5.50000e-05
# 121                4.00000e-05

# %%
# Table 2
# Bottom 10 countries by coverage: The 10 countries with the lowest total articles per capita (asc)
article_count_per_country_population.sort_values('total_articles_per_capita').head(10)
# Out:
#            country   population  total_article_count  \
# 31           China  1.41130e+09                   16
# 66           India  1.42860e+09                  151
# 57           Ghana  3.41000e+07                    4
# 122   Saudi Arabia  3.69000e+07                    5
# 164         Zambia  2.02000e+07                    3
# 108         Norway  5.50000e+06                    1
# 70          Israel  9.80000e+06                    2
# 45           Egypt  1.05200e+08                   32
# 37   Cote d'Ivoire  3.09000e+07                   10
# 50        Ethiopia  1.26500e+08                   44
#
#      total_articles_per_capita
# 31                 1.13371e-08
# 66                 1.05698e-07
# 57                 1.17302e-07
# 122                1.35501e-07
# 164                1.48515e-07
# 108                1.81818e-07
# 70                 2.04082e-07
# 45                 3.04183e-07
# 37                 3.23625e-07
# 50                 3.47826e-07

# %%
# Table 3
# Top 10 countries by high quality: The 10 countries with the highest high quality articles per capita (desc)
high_quality_article_count_by_country_population_df.sort_values('high_quality_articles_per_capita', ascending=False).head(10)
# Out:
#                    country   population  total_high_quality_article_count  \
# 98              Montenegro  6.00000e-01                                 3
# 86              Luxembourg  7.00000e-01                                 2
# 1                  Albania  2.70000e+00                                 7
# 76                  Kosovo  1.70000e+00                                 3
# 90                Maldives  6.00000e-01                                 1
# 85               Lithuania  2.90000e+00                                 4
# 38                 Croatia  3.80000e+00                                 5
# 62                  Guyana  8.00000e-01                                 1
# 111  Palestinian Territory  5.50000e+00                                 6
# 129               Slovenia  2.10000e+00                                 2
#
#      high_quality_articles_per_capita
# 98                        5.00000e+00
# 86                        2.85714e+00
# 1                         2.59259e+00
# 76                        1.76471e+00
# 90                        1.66667e+00
# 85                        1.37931e+00
# 38                        1.31579e+00
# 62                        1.25000e+00
# 111                       1.09091e+00
# 129                       9.52381e-01

# %%
# Table 4
# Bottom 10 countries by high quality: The 10 countries with the lowest high quality articles per capita (asc)
high_quality_article_count_by_country_population_df[high_quality_article_count_by_country_population_df['high_quality_articles_per_capita'] == 0]
# Out:
#                  country   population  total_high_quality_article_count  \
# 4    Antigua and Barbuda  1.00000e-01                                 0
# 9                Bahamas  4.00000e-01                                 0
# 12              Barbados  3.00000e-01                                 0
# 15                Belize  5.00000e-01                                 0
# 16                 Benin  1.37000e+01                                 0
# ..                   ...          ...                               ...
# 159           Uzbekistan  3.64000e+01                                 0
# 160              Vanuatu  3.00000e-01                                 0
# 163                Yemen  3.44000e+01                                 0
# 164               Zambia  2.02000e+01                                 0
# 165             Zimbabwe  1.67000e+01                                 0
#
#      high_quality_articles_per_capita
# 4                         0.00000e+00
# 9                         0.00000e+00
# 12                        0.00000e+00
# 15                        0.00000e+00
# 16                        0.00000e+00
# ..                                ...
# 159                       0.00000e+00
# 160                       0.00000e+00
# 163                       0.00000e+00
# 164                       0.00000e+00
# 165                       0.00000e+00
#
# [63 rows x 4 columns]

# %%
# Table 5
# Geographic regions by total coverage: A rank ordered list of geographic regions (desc) by total articles per capita
high_quality_article_count_by_region_population_df.sort_values('total_articles_per_capita', ascending=False)
# Out:
#              region   population  total_article_count  \
# 14  SOUTHERN EUROPE  1.52000e+08                  797
# 0         CARIBBEAN  4.40000e+07                  219
# 17   WESTERN EUROPE  1.99000e+08                  498
# 5    EASTERN EUROPE  2.85000e+08                  709
# 16     WESTERN ASIA  2.99000e+08                  610
# 8   NORTHERN EUROPE  1.08000e+08                  191
# 13  SOUTHERN AFRICA  7.00000e+07                  123
# 9           OCEANIA  4.50000e+07                   72
# 4    EASTERN AFRICA  4.83000e+08                  665
# 10    SOUTH AMERICA  4.26000e+08                  569
# 2      CENTRAL ASIA  8.00000e+07                  106
# 7   NORTHERN AFRICA  2.56000e+08                  302
# 15   WESTERN AFRICA  4.42000e+08                  515
# 6     MIDDLE AFRICA  2.02000e+08                  231
# 1   CENTRAL AMERICA  1.82000e+08                  188
# 12   SOUTHEAST ASIA  6.82000e+08                  396
# 11       SOUTH ASIA  2.02900e+09                  670
# 3         EAST ASIA  1.64800e+09                  152
#
#     total_articles_per_capita
# 14                5.24342e-06
# 0                 4.97727e-06
# 17                2.50251e-06
# 5                 2.48772e-06
# 16                2.04013e-06
# 8                 1.76852e-06
# 13                1.75714e-06
# 9                 1.60000e-06
# 4                 1.37681e-06
# 10                1.33568e-06
# 2                 1.32500e-06
# 7                 1.17969e-06
# 15                1.16516e-06
# 6                 1.14356e-06
# 1                 1.03297e-06
# 12                5.80645e-07
# 11                3.30212e-07
# 3                 9.22330e-08

# %%
# Table 6
# Geographic regions by high quality coverage: A rank ordered list of geographic regions (desc) by high quality articles per capita
high_quality_article_count_by_region_population_df.sort_values('high_quality_articles_per_capita', ascending=False)
# Out:
#              region   population  total_high_quality_article_count  \
# 14  SOUTHERN EUROPE  1.52000e+02                                52
# 0         CARIBBEAN  4.40000e+01                                 9
# 5    EASTERN EUROPE  2.85000e+02                                38
# 13  SOUTHERN AFRICA  7.00000e+01                                 8
# 17   WESTERN EUROPE  1.99000e+02                                21
# 16     WESTERN ASIA  2.99000e+02                                27
# 8   NORTHERN EUROPE  1.08000e+02                                 9
# 7   NORTHERN AFRICA  2.56000e+02                                17
# 2      CENTRAL ASIA  8.00000e+01                                 5
# 1   CENTRAL AMERICA  1.82000e+02                                10
# 10    SOUTH AMERICA  4.26000e+02                                19
# 6     MIDDLE AFRICA  2.02000e+02                                 8
# 12   SOUTHEAST ASIA  6.82000e+02                                25
# 4    EASTERN AFRICA  4.83000e+02                                17
# 15   WESTERN AFRICA  4.42000e+02                                13
# 9           OCEANIA  4.50000e+01                                 1
# 11       SOUTH ASIA  2.02900e+03                                21
# 3         EAST ASIA  1.64800e+03                                 3
#
#     high_quality_articles_per_capita
# 14                       3.42105e-01
# 0                        2.04545e-01
# 5                        1.33333e-01
# 13                       1.14286e-01
# 17                       1.05528e-01
# 16                       9.03010e-02
# 8                        8.33333e-02
# 7                        6.64062e-02
# 2                        6.25000e-02
# 1                        5.49451e-02
# 10                       4.46009e-02
# 6                        3.96040e-02
# 12                       3.66569e-02
# 4                        3.51967e-02
# 15                       2.94118e-02
# 9                        2.22222e-02
# 11                       1.03499e-02
# 3                        1.82039e-03
